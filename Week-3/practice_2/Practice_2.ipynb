# %%
import tkinter as tk 

#Handling button click event 
def button_click():
    #print(" Button clciked !")

    #show an information message box 
    msgbox.showinfo("Info", " Welcome to COS 102 GUI
