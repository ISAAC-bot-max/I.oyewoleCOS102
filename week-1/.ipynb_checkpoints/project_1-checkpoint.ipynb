# %%
#calculator for the interest 

print("\n Simple Interest")
P = float(input("Enter Principal: "))
R = float(input("Enter Rate : ")) 
T = float(input("Enter Time: "))
SI = (P * R * T)/100
A = P + SI
print("The simple Interest: ",SI)
# Out:
#  CALCULATOR
# What would you like to calculate
# 1. Simple Interest
# 2. Compound Interest
# 3. Annuity Plan
# Choose an option (1-3):  1
#  Simple Interest
# Enter Principal:  300.67
# Enter Rate :  4
# Enter Time:  3
# The simple Interest:  36.0804
# The final amount is :  336.7504
