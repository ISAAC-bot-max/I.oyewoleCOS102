# %%
print(" Welcome to  Izifin Technology ")

# Input
experience = int(input("Enter staff years of experience: "))
age = int(input("Enter staff age: "))

# Decision structure
if experience > 25 and age >= 55:
    atr = 5600000
elif experience > 20 and age >= 45:
    atr = 4480000
elif experience > 10 and age >= 35:
    atr = 1500000
else:
    atr = 550000

# Output
print("Annual Tax Revenue (ATR): ₦", atr)
# Out:
#  Welcome to  Izifin Technology
# Enter staff years of experience:  45
# Enter staff age:  33
# Annual Tax Revenue (ATR): ₦ 550000
